# %% [markdown]
# CNN - FACE RECOGINITION CLASSIFICATION- EMOTION, RACE, GENDER ANALYSIS

# %%
import cv2

# %% [markdown]
# cv2 is the

# %%
# Load an image
img=cv2.imread("/content/facc64361b2aae400ade3a3321b4ab5a.jpg")

# %%
# import matplotlib
import matplotlib.pyplot as plt

# %%
# Convert the image from BGR to Grayscale
plt.imshow(img) # BGR

# %%
# Converting BGR TO RGB
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) #RGB

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 37.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=f90c9d227198f3bac92d6fcebedff60f04564046e3bcbbfe81f2dd5c9dd85a8a
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
from deepface import DeepFace
pred=DeepFace.analyze(img)
# Out:
# 24-09-11 11:19:46 - Directory /root/.deepface has been created
# 24-09-11 11:19:46 - Directory /root/.deepface/weights has been created
# Action: emotion:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-09-11 11:19:47 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
#
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 85.4MB/s]
# Action: age:  25%|██▌       | 1/4 [00:01<00:03,  1.09s/it]
# 24-09-11 11:19:50 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   2%|▏         | 11.0M/539M [00:00<00:06, 87.3MB/s]
#   4%|▍         | 22.5M/539M [00:00<00:05, 100MB/s]
# ...

# %%
(pred)
# Out:
# [{'emotion': {'angry': 58.42834115028381,
#    'disgust': 0.000542193129149382,
#    'fear': 5.180053785443306,
#    'happy': 0.012772477930411696,
#    'sad': 26.901578903198242,
#    'surprise': 0.019590639567468315,
#    'neutral': 9.457121789455414},
#   'dominant_emotion': 'angry',
#   'region': {'x': 137,
#    'y': 156,
#    'w': 217,
#    'h': 217,
#    'left_eye': (290, 243),
#    'right_eye': (205, 244)},
#   'face_confidence': 0.93,
#   'age': 31,
#   'gender': {'Woman': 99.99798536300659, 'Man': 0.002019926796492655},
#   'dominant_gender': 'Woman',
#   'race': {'asian': 1.9566863775253296,
#    'indian': 2.7838604524731636,
#    'black': 0.7492240983992815,
#    'white': 49.06545579433441,
#    'middle eastern': 14.502495527267456,
#    'latino hispanic': 30.942276120185852},
#   'dominant_race': 'white'}]

# %%
prediction=pred[0]
prediction["dominant_emotion"]
# Out:
# 'angry'

# %%
prediction["gender"]
# Out:
# {'Woman': 99.99798536300659, 'Man': 0.002019926796492655}

# %%
prediction["race"]
# Out:
# {'asian': 1.9566863775253296,
#  'indian': 2.7838604524731636,
#  'black': 0.7492240983992815,
#  'white': 49.06545579433441,
#  'middle eastern': 14.502495527267456,
#  'latino hispanic': 30.942276120185852}
